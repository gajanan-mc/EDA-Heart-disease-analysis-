# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
dil = pd.read_csv('heart.csv')

# %%
dil.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
dil.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
dil.shape
# Out:
# (303, 14)

# %%
dil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
dil.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
dil.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# # Univariate analysis

# %%
dil['target'].nunique()
# Out:
# 2

# %%
dil['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
dil['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
# it will give us the count of unique values in the that feature on which we are using this function

# %%
sns.countplot(data = dil, x='target')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
dil.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: target, dtype: int64

# %%
f , ax = plt.subplots(figsize=(8,5))
ax = sns.countplot(data =dil, x = 'target',hue = 'sex')
plt.show()

# %%
ax = sns.catplot(data =dil, x = 'target',col = 'sex',kind = 'count',height=5)

# %%
ax = sns.catplot(data =dil, x = 'target',col = 'sex',kind = 'count',height=5)

# %%
dil.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(y ='target',hue = 'sex',data =dil)
# Out:
# <Axes: xlabel='count', ylabel='target'>

# %%
sns.countplot(x = 'target',data = dil,palette='Set3')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
f , ax = plt.subplots(figsize =(8,5))
ax = sns.countplot(x = 'target',data = dil,facecolor=(0,1,0,0),linewidth =4,edgecolor = sns.color_palette('dark',3) )
plt.show()

# %%
sns.countplot(x = 'target',data = dil, linewidth =5,edgecolor = sns.color_palette('bright',4),facecolor=(1,1,1,1))
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
sns.countplot(x = 'target',hue = 'fbs',data = dil)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
sns.countplot(x = 'target',hue='exang',data = dil)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# # bivariate analysis

# %%
correlation = dil.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
dil.cp.nunique()
# Out:
# 4

# %%
dil['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
sns.countplot(x = 'cp', data = dil)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
dil.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: target, dtype: int64

# %%
sns.countplot(x = 'cp',hue = 'target',data = dil)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
sns.catplot(x ='target', col = 'cp',data = dil,kind ='count',height = 5,aspect=1)
plt.show()

# %%
dil['thalach'].nunique()
# Out:
# 91

# %% [markdown]
# # to visualize this thalach feature distribution

# %%
sns.set_style('darkgrid')
sns.distplot(dil['thalach'])
# Out:
# <Axes: xlabel='thalach', ylabel='Density'>

# %%
# we can plot it vertically also 

sns.distplot(dil['thalach'],bins =12,vertical=True)
# Out:
# <Axes: xlabel='Density', ylabel='thalach'>

# %%
sns.kdeplot(data = dil, x = 'thalach')
# Out:
# <Axes: xlabel='thalach', ylabel='Density'>

# %%
sns.kdeplot(data = dil, x = 'thalach',shade=True,color = 'green')
# Out:
# <Axes: xlabel='thalach', ylabel='Density'>

# %%
sns.distplot(dil['thalach'],kde = False)
# Out:
# <Axes: xlabel='thalach'>

# %%
sns.stripplot(data =dil,y = 'thalach',x= 'target',hue = 'target')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
# to check if this values of heart disease patient have any outlier values we plot boxlot

sns.boxplot(data = dil,x = 'target',y = 'thalach')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %% [markdown]
# # Multivariate analysis

# %%
plt.figure(figsize=(16,12))
sns.heatmap(correlation,annot=True,fmt = '.2f')
# Out:
# <Axes: >

# %%
num = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]

sns.pairplot(dil[num],diag_kind='hist')

# %%
sns.boxplot(data = dil, x = dil['target'],y = 'age')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.scatterplot(x="age", y="trestbps", data=dil)
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.regplot(x="age", y="trestbps", data=dil)
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.scatterplot(x="age", y="chol", data=dil)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.scatterplot(x="age", y="chol", data=dil)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.regplot(x = "age", y ="chol", data = dil)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %% [markdown]
# ## Analyze chol and thalach variable

# %%
sns.scatterplot(data = dil, x = 'chol',y = 'thalach')
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %%
sns.regplot(data  =dil, x = 'chol', y = 'thalach')
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %% [markdown]
# ## Check with ASSERT statement

# %%
assert pd.notnull(dil).all().all()

# %% [markdown]
# ### it returns nothing means we don't have null values in the data set if it gives error then we have null values in the dataset.

# %% [markdown]
# ## Outlier detection

# %%
fig , ax = plt.subplots(figsize=(10,5))
sns.boxplot(dil[['age','thalach','chol','trestbps']])
# Out:
# <Axes: >

# %%
sns.boxplot(dil['oldpeak'])
# Out:
# <Axes: >

# %% [markdown]
# ### Here we can see we have outliers in the dataset by using boxplot.
